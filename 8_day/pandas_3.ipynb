# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Groupby, Working with Text data, Creating Panda Series, Merging, Joining, Concatenation

# %% [markdown]
# # Groupby

# %% [markdown]
# Groupby is a pretty simple concept.
#
# We can create a grouping of categories and apply a function to the categories.
#
# It’s a simple concept but it’s an extremely valuable technique that’s widely used in data science.
#
# In real data science projects, you’ll be dealing with large amounts of data and trying things over and over, so for efficiency.
#
# We use Groupby concept. Groupby concept is really important because it’s ability to aggregate data efficiently, both in performance and the amount code is magnificent.

# %% [markdown]
# Groupby mainly refers to a process involving one or more of the following steps they are:
#
# Splitting : It is a process in which we split data into group by applying some conditions on datasets.
#
# Applying : It is a process in which we apply a function to each group independently
#
# Combining : It is a process in which we combine different datasets after applying groupby and results into a data structure

# %%
# Grouping data with one key: 
# In order to group data with one key, we pass only one key as an argument in groupby function. 
import pandas as pd
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}
df = pd.DataFrame(data1)
print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
#Now we print the first entries in all the groups formed. 
gk = df.groupby('Name')
gk.first()
# Out:
#         Age  Address Qualification
# Name
# Abhi     32  Aligarh            MA
# Anuj     24   Kanpur            MA
# Gaurav   33  Jaunpur        B.Tech
# Jai      27   Nagpur           Msc
# Princi   32  Kannuaj           Phd

# %%
# Grouping data with Multiple Keys
df.groupby(['Name', 'Qualification'])
print(df.groupby(['Name', 'Qualification']).groups)
df.groupby(['Name']).sum()
# Out:
# {('Abhi', 'MA'): [7], ('Anuj', 'B.com'): [5], ('Anuj', 'MA'): [1], ('Gaurav', 'B.Tech'): [4], ('Jai', 'MCA'): [2], ('Jai', 'Msc'): [0], ('Princi', 'Msc'): [6], ('Princi', 'Phd'): [3]}
#         Age           Address Qualification
# Name
# Abhi     32           Aligarh            MA
# Anuj     60      KanpurKanpur       MAB.com
# Gaurav   33           Jaunpur        B.Tech
# Jai      49   NagpurAllahabad        MscMCA
# Princi   59  KannuajAllahabad        PhdMsc

# %%
# Iterating element of group 
grp = df.groupby('Name')
for name, group in grp:
    print(name)
    print(group)
    print()
# Out:
# Abhi
#    Name  Age  Address Qualification
# 7  Abhi   32  Aligarh            MA
#
# Anuj
#    Name  Age Address Qualification
# 1  Anuj   24  Kanpur            MA
# 5  Anuj   36  Kanpur         B.com
#
# Gaurav
#      Name  Age  Address Qualification
# 4  Gaurav   33  Jaunpur        B.Tech
#
# Jai
#   Name  Age    Address Qualification
# 0  Jai   27     Nagpur           Msc
# 2  Jai   22  Allahabad           MCA
#
# Princi
#      Name  Age    Address Qualification
# 3  Princi   32    Kannuaj           Phd
# 6  Princi   27  Allahabad           Msc

# %%
# Selecting a Group
grp = df.groupby('Name')
grp.get_group('Jai')
# Out:
#   Name  Age    Address Qualification
# 0  Jai   27     Nagpur           Msc
# 2  Jai   22  Allahabad           MCA

# %%
# Aggregation
import pandas as pd
import numpy as np
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}
df = pd.DataFrame(data1)
print(df)
grp1 = df.groupby('Name')
grp1.aggregate(np.sum)
# abc = grp1.aggregate("sum")
# print(abc)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA
#         Age           Address Qualification
# Name
# Abhi     32           Aligarh            MA
# Anuj     60      KanpurKanpur       MAB.com
# Gaurav   33           Jaunpur        B.Tech
# Jai      49   NagpurAllahabad        MscMCA
# Princi   59  KannuajAllahabad        PhdMsc
# C:\Users\VIJAY\AppData\Local\Temp\ipykernel_4952\1121731443.py:15: FutureWarning: The provided callable <function sum at 0x000002199A3E20C0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp1.aggregate(np.sum)

# %%
# Passing List of functions 
grp = df.groupby('Name')
grp['Age'].agg([np.sum, np.mean, np.std])
# Out:
# C:\Users\VIJAY\AppData\Local\Temp\ipykernel_4952\3244103154.py:3: FutureWarning: The provided callable <function sum at 0x000002199A3E20C0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp['Age'].agg([np.sum, np.mean, np.std])
# C:\Users\VIJAY\AppData\Local\Temp\ipykernel_4952\3244103154.py:3: FutureWarning: The provided callable <function mean at 0x000002199A3E31A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp['Age'].agg([np.sum, np.mean, np.std])
# C:\Users\VIJAY\AppData\Local\Temp\ipykernel_4952\3244103154.py:3: FutureWarning: The provided callable <function std at 0x000002199A3E32E0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   grp['Age'].agg([np.sum, np.mean, np.std])
#         sum  mean       std
# Name
# Abhi     32  32.0       NaN
# Anuj     60  30.0  8.485281
# Gaurav   33  33.0       NaN
# Jai      49  24.5  3.535534
# Princi   59  29.5  3.535534

# %%
# Applying different functions to different columns
grp = df.groupby('Name')
grp.agg({'Age' : 'sum', 'Score' : 'std'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Applying different functions to different columns
#       2 grp = df.groupby('Name')
# ----> 3 grp.agg({'Age' : 'sum', 'Score' : 'std'})
#
# File c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\groupby\generic.py:1445, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1442     kwargs["engine_kwargs"] = engine_kwargs
#    1444 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1445 result = op.agg()
#    1446 if not is_dict_like(func) and result is not None:
#    1447     # GH #52849
#    1448     if not self.as_index and is_list_like(func):
#
# File c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\apply.py:175, in Apply.agg(self)
#     172     return self.apply_str()
#     174 if is_dict_like(func):
# --> 175     return self.agg_dict_like()
#     176 elif is_list_like(func):
#     177     # we require a list, but not a 'str'
#     178     return self.agg_list_like()
#
# File c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\apply.py:406, in Apply.agg_dict_like(self)
#     398 def agg_dict_like(self) -> DataFrame | Series:
#     399     """
#     400     Compute aggregation in the case of a dict-like argument.
#     401
#    (...)
#     404     Result of aggregation.
#     405     """
# --> 406     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\apply.py:1390, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1385     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1387 with com.temp_setattr(
#    1388     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1389 ):
# -> 1390     result_index, result_data = self.compute_dict_like(
#    1391         op_name, selected_obj, selection, kwargs
#    1392     )
#    1393 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1394 return result
#
# File c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\apply.py:445, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     443 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     444 func = cast(AggFuncTypeDict, self.func)
# --> 445 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     447 is_non_unique_col = (
#     448     selected_obj.ndim == 2
#     449     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     450 )
#     452 if selected_obj.ndim == 1:
#     453     # key only used for output
#
# File c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\apply.py:639, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     637     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     638     if len(cols) > 0:
# --> 639         raise KeyError(f"Column(s) {list(cols)} do not exist")
#     641 aggregator_types = (list, tuple, dict)
#     643 # if we have a dict of any non-scalars
#     644 # eg. {'A' : ['mean']}, normalize all to
#     645 # be list-likes
#     646 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Score'] do not exist"

# %% [markdown]
# # Working with text data.

# %%
# Lowercasing and Uppercasing Data
import pandas as pd 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
df = pd.DataFrame(data) 
df["Name"]= df["Name"].str.lower()
print(df)
# Out:
#      Name  Age    Address Qualification
# 0     jai   27      Delhi           Msc
# 1  princi   24     Kanpur            MA
# 2  gaurav   22  Allahabad           MCA
# 3    anuj   32    Kannauj           Phd

# %%
import pandas as pd 
data = pd.read_csv('unigram_freq.csv') 
print(data)
data['word']= data['word'].str.upper() 
print(data)
# Out:
#            word        count
# 0           the  23135851162
# 1            of  13151942776
# 2           and  12997637966
# 3            to  12136980858
# 4             a   9081174698
# ...         ...          ...
# 333328    gooek        12711
# 333329   gooddg        12711
# 333330  gooblle        12711
# 333331   gollgo        12711
# 333332    golgw        12711
#
# [333333 rows x 2 columns]
#            word        count
# 0           THE  23135851162
# 1            OF  13151942776
# 2           AND  12997637966
# 3            TO  12136980858
# 4             A   9081174698
# ...         ...          ...
# 333328    GOOEK        12711
# 333329   GOODDG        12711
# 333330  GOOBLLE        12711
# 333331   GOLLGO        12711
# 333332    GOLGW        12711
#
# [333333 rows x 2 columns]

# %%
import pandas as pd

# Creating a DataFrame from a dictionary
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age': [27, 24, 22, 32],
        'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Knnuaj'],
        'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

df = pd.DataFrame(data)
print(df,'\n\n')
# Dropping rows with missing values (NaN)
df.dropna(inplace=True)

# Splitting the "Address" column into two new columns
df[['Address_1', 'Address_2']] = df["Address"].str.split("a", n=1, expand=True)

# Dropping the original "Address" column
df.drop(columns=['Address'], inplace=True)

# Printing the resulting DataFrame
print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32     Knnuaj           Phd
#
#
#      Name  Age Qualification Address_1 Address_2
# 0     Jai   27           Msc         N      gpur
# 1  Princi   24            MA         K      npur
# 2  Gaurav   22           MCA       All     habad
# 3    Anuj   32           Phd      Knnu         j

# %%
#Splitting and Replacing Data
import pandas as pd
data = pd.read_csv("unigram_freq.csv")
print(data, '\n\n')
data['count']= data["count"].replace(8, "EIGHT")
filter = data["count"]=="EIGHT"
data.where(filter).dropna()
print(data.head(10))
# Out:
#            word        count
# 0           the  23135851162
# 1            of  13151942776
# 2           and            8
# 3            to  12136980858
# 4             a   9081174698
# ...         ...          ...
# 333328    gooek        12711
# 333329   gooddg        12711
# 333330  gooblle        12711
# 333331   gollgo        12711
# 333332    golgw        12711
#
# [333333 rows x 2 columns]
#
#
#    word        count
# 0   the  23135851162
# 1    of  13151942776
# 2   and        EIGHT
# 3    to  12136980858
# 4     a   9081174698
# 5    in   8469404971
# 6   for   5933321709
# 7    is   4705743816
# 8    on   3750423199
# 9  that   3400031103

# %%
# Concatenation of Data
import pandas as pd 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
df = pd.DataFrame(data) 
print(df)

new = df["Address"].copy() 
df["Name"]= df["Name"].str.cat(new, sep =", ") 
print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#                 Name  Age    Address Qualification
# 0        Jai, Nagpur   27     Nagpur           Msc
# 1     Princi, Kanpur   24     Kanpur            MA
# 2  Gaurav, Allahabad   22  Allahabad           MCA
# 3      Anuj, Kannuaj   32    Kannuaj           Phd

# %%
import pandas as pd
data = pd.read_excel('Athletes.xlsx')
new = data['Country'].copy()
data['Athlete']= data["Athlete"].str.cat(new, sep =", ")
data
# Out:
#                               Athlete   Age        Country  Year  \
# 0       Michael Phelps, United States  23.0  United States  2008
# 1       Michael Phelps, United States  19.0  United States  2004
# 2       Michael Phelps, United States  27.0  United States  2012
# 3     Natalie Coughlin, United States  25.0  United States  2008
# 4               Aleksey Nemov, Russia  24.0         Russia  2000
# ...                               ...   ...            ...   ...
# 8613        Olena Sadovnycha, Ukraine  32.0        Ukraine  2000
# 8614        Kateryna Serdiuk, Ukraine  17.0        Ukraine  2000
# 8615    Wietse van Alten, Netherlands  21.0    Netherlands  2000
# 8616    Sandra Wagner-Sachse, Germany  31.0        Germany  2000
# 8617         Rod White, United States  23.0  United States  2000
#
#      Closing Ceremony Date       Sport  Gold Medals  Silver Medals  \
# 0               2008-08-24    Swimming            8              0
# 1               2004-08-29    Swimming            6              0
# 2               2012-08-12    Swimming            4              2
# 3               2008-08-24    Swimming            1              2
# 4               2000-10-01  Gymnastics            2              1
# ...                    ...         ...          ...            ...
# 8613            2000-10-01     Archery            0              1
# 8614            2000-10-01     Archery            0              1
# 8615            2000-10-01     Archery            0              0
# 8616            2000-10-01     Archery            0              0
# 8617            2000-10-01     Archery            0              0
#
#       Bronze Medals  Total Medals
# 0                 0             8
# 1                 2             8
# 2                 0             6
# 3                 3             6
# 4                 3             6
# ...             ...           ...
# 8613              0             1
# 8614              0             1
# 8615              1             1
# 8616              1             1
# 8617              1             1
#
# [8618 rows x 10 columns]

# %%
# Removing Whitespaces of Data
import pandas as pd 
data = pd.read_excel('Athletes.xlsx') 
new = data["Country"].replace('Russia', "  Russia  ").copy() 
new.str.lstrip()=='Russia  '
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8613    False
# 8614    False
# 8615    False
# 8616    False
# 8617    False
# Name: Country, Length: 8618, dtype: bool

# %% [markdown]
# # Creating a pandas series

# %%
# Creating an empty Series :
# A basic series, which can be created is an Empty Series.
import pandas as pd
ser = pd.Series()
print(ser)
# Out:
# Series([], dtype: object)

# %%
# Creating a series from array
import pandas as pd
import numpy as np
data = np.array(['g', 'o','o', 'd', 's'])
ser = pd.Series(data)
print(ser)
# Out:
# 0    g
# 1    o
# 2    o
# 3    d
# 4    s
# dtype: object

# %%
# Creating a series from array with index :
import pandas as pd
import numpy as np
data = np.array(['g', 'o', 'o', 'd', 's'])
ser = pd.Series(data, index =[10, 11, 12, 13, 14])
print(ser)
# Out:
# 10    g
# 11    o
# 12    o
# 13    d
# 14    s
# dtype: object

# %%
# Creating a series from Lists:
import pandas as pd
list = ['g', 'o', 'o', 'd', 's']
ser = pd.Series(list)
print(ser)
# Out:
# 0    g
# 1    o
# 2    o
# 3    d
# 4    s
# dtype: object

# %%
# Creating a series from Dictionary:
import pandas as pd
dict = {'Germany' : 10,
        'france' : 20,
        'Ireland' : 30}
ser = pd.Series(dict)
print(ser)
# Out:
# Germany    10
# france     20
# Ireland    30
# dtype: int64

# %%
# Creating a series from Scalar value:
import pandas as pd
import numpy as np
ser = pd.Series(10, index =[0, 1, 2, 3, 4, 5])
print(ser)
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# dtype: int64

# %%
# Creating a series using NumPy functions :
import pandas as pd 
import numpy as np 
ser1 = pd.Series(np.linspace(3, 33, 3)) 
print(ser1) 
ser2 = pd.Series(np.linspace(1, 100, 10)) 
print("\n", ser2)
# Out:
# 0     3.0
# 1    18.0
# 2    33.0
# dtype: float64
#
#  0      1.0
# 1     12.0
# 2     23.0
# 3     34.0
# 4     45.0
# 5     56.0
# 6     67.0
# 7     78.0
# 8     89.0
# 9    100.0
# dtype: float64

# %%
# We can join, merge, and concat dataframe using different methods. 
# In Dataframe df.merge(),df.join(), and df.concat() methods
# help in joining, merging and concating different dataframe.

# Concatenating DataFrame
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 
        'Age':[17, 14, 12, 52], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

# %%
print(data1, '\n\n', data2)
# Out:
# {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'], 'Age': [27, 24, 22, 32], 'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}
#
#  {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 'Age': [17, 14, 12, 52], 'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}

# %%
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7]) 
print(df, "\n\n", df1) 
frames = [df, df1] 
res1 = pd.concat(frames)
res1
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 4  Gaurav   22  Allahabad           MCA    1000
# 5    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 4  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 5    Anuj   32    Kannuaj           Phd        NaN  2000.0
# 6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
# 7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %%
# Concatenating DataFrame by setting logic on axes :
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]} 
data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]}

# %%
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7]) 
print(df, "\n\n", df1) 
res2 = pd.concat([df, df1], axis=1, join='inner')
res2
res2 = pd.concat([df, df1], axis=1, sort=False)
res2
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#      Name   Age    Address Qualification  Mobile No    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc       97.0     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA       91.0     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA       58.0  Gaurav  22.0  Allahabad
# 3    Anuj  32.0    Kannuaj           Phd       76.0    Anuj  32.0    Kannuaj
# 6     NaN   NaN        NaN           NaN        NaN  Dhiraj  12.0  Allahabad
# 7     NaN   NaN        NaN           NaN        NaN  Hitesh  52.0    Kannuaj
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2           MCA  1000.0
# 3           Phd  2000.0
# 6          Bcom  3000.0
# 7        B.hons  4000.0

# %%
# Concatenating DataFrame using .append()
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 
        'Age':[17, 14, 12, 52], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7]) 
print(df, "\n\n", df1) 
res = df.append(df1)
res
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23768\2413146268.py in ?()
#      10         'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}
#      11 df = pd.DataFrame(data1,index=[0, 1, 2, 3])
#      12 df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])
#      13 print(df, "\n\n", df1)
# ---> 14 res = df.append(df1)
#      15 res
#
# c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import pandas as pd

# Creating the first DataFrame (df)
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}
df = pd.DataFrame(data1, index=[0, 1, 2, 3])

# Creating the second DataFrame (df1)
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

# Printing the original DataFrames
print(df, "\n\n", df1)

# Concatenating the DataFrames using .append()
res = df.append(df1)

# Displaying the resulting DataFrame
print(res)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23768\2516464986.py in ?()
#      17 # Printing the original DataFrames
#      18 print(df, "\n\n", df1)
#      19
#      20 # Concatenating the DataFrames using .append()
# ---> 21 res = df.append(df1)
#      22
#      23 # Displaying the resulting DataFrame
#      24 print(res)
#
# c:\Users\VIJAY\OneDrive\Desktop\ITC\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import pandas as pd

# Creating the first DataFrame (df)
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}
df = pd.DataFrame(data1, index=[0, 1, 2, 3])

# Creating the second DataFrame (df1)
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

# Printing the original DataFrames
print(df, "\n\n", df1)

# Checking for any variable named 'append'
if 'append' in dir(pd.DataFrame):
    # If 'append' is present, use it as a method
    res = df.append(df1)
else:
    # If not, try using the pandas method directly
    res = pd.concat([df, df1])

# Displaying the resulting DataFrame
print(res)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
if 'append' in dir(pd.DataFrame):
    print("true")
else :
    print("False")
# Out:
# False

# %%
# Concatenating DataFrame by ignoring indexes :
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd'],
        'Mobile No': [97, 91, 58, 76]} 
data2 = {'Name':['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'], 
        'Age':[22, 32, 12, 52], 
        'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons'],
        'Salary':[1000, 2000, 3000, 4000]} 
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7]) 
print(df, "\n\n", df1) 
res = pd.concat([df, df1], ignore_index=True) 
res
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000
#      Name  Age    Address Qualification  Mobile No  Salary
# 0     Jai   27     Nagpur           Msc       97.0     NaN
# 1  Princi   24     Kanpur            MA       91.0     NaN
# 2  Gaurav   22  Allahabad           MCA       58.0     NaN
# 3    Anuj   32    Kannuaj           Phd       76.0     NaN
# 4  Gaurav   22  Allahabad           MCA        NaN  1000.0
# 5    Anuj   32    Kannuaj           Phd        NaN  2000.0
# 6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
# 7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %%
# Concatenating DataFrame with group keys :
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'], 
        'Age':[17, 14, 12, 52], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])
print(df, "\n\n", df1)
frames = [df, df1 ]
res = pd.concat(frames, keys=['x', 'y'])
res
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons
#        Name  Age    Address Qualification
# x 0     Jai   27     Nagpur           Msc
#   1  Princi   24     Kanpur            MA
#   2  Gaurav   22  Allahabad           MCA
#   3    Anuj   32    Kannuaj           Phd
# y 4    Abhi   17     Nagpur         Btech
#   5  Ayushi   14     Kanpur           B.A
#   6  Dhiraj   12  Allahabad          Bcom
#   7  Hitesh   52    Kannuaj        B.hons

# %%
# Concatenating with mixed ndims 
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
s1 = pd.Series([1000, 2000, 3000, 4000], name='Salary')
print(df, "\n\n", s1) 
res = pd.concat([df, s1], axis=1)
res
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: Salary, dtype: int64
#      Name  Age    Address Qualification  Salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannuaj           Phd    4000

# %%
# Merging DataFrame
import pandas as pd 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2) 
print(df, "\n\n", df1) 
res = pd.merge(df, df1, on='key')
res
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32
#
#    key    Address Qualification
# 0  K0     Nagpur         Btech
# 1  K1     Kanpur           B.A
# 2  K2  Allahabad          Bcom
# 3  K3    Kannuaj        B.hons
#   key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %%
import pandas as pd 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2) 
print(df, "\n\n", df1) 
res1 = pd.merge(df, df1, on=['key', 'key1'])
res1
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#
#    key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
# Merging dataframe using how in an argument:
import pandas as pd 
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],} 
data2 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'key1': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2) 
print(df, "\n\n", df1) 
res = pd.merge(df, df1, how='left', on=['key', 'key1'])
res
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32
#
#    key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   22  Allahabad          Bcom
# 3  K3   K1    Anuj   32        NaN           NaN

# %%
# Now we set how = 'right' in order to use keys from right frame only.
res1 = pd.merge(df, df1, how='right', on=['key', 'key1'])
res1
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K0     NaN   NaN     Kanpur           B.A
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
# Now we set how = 'outer' in order to get union of keys from dataframes.
res2 = pd.merge(df, df1, how='outer', on=['key', 'key1']) 
res2
# Out:
#   key key1    Name   Age    Address Qualification
# 0  K0   K0     Jai  27.0     Nagpur         Btech
# 1  K1   K1  Princi  24.0        NaN           NaN
# 2  K2   K0  Gaurav  22.0  Allahabad          Bcom
# 3  K3   K1    Anuj  32.0        NaN           NaN
# 4  K1   K0     NaN   NaN     Kanpur           B.A
# 5  K3   K0     NaN   NaN    Kannuaj        B.hons

# %%
# Now we set how = 'inner' in order to get intersection of keys from dataframes.
res3 = pd.merge(df, df1, how='inner', on=['key', 'key1'])
res3
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
# Joining DataFrame
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32]} 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1,index=['K0', 'K1', 'K2', 'K3'])
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4']) 
print(df, "\n\n", df1)  
res = df.join(df1)
res
# Out:
#       Name  Age
# K0     Jai   27
# K1  Princi   24
# K2  Gaurav   22
# K3    Anuj   32
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons
#       Name  Age    Address Qualification
# K0     Jai   27  Allahabad           MCA
# K1  Princi   24        NaN           NaN
# K2  Gaurav   22    Kannuaj           Phd
# K3    Anuj   32  Allahabad          Bcom

# %%
# Joining dataframe using on in an argument :
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32],
        'Key':['K0', 'K1', 'K2', 'K3']} 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2, index=['K0', 'K2', 'K3', 'K4'])
print(df, "\n\n", df1) 
res2 = df.join(df1, on='Key')
res2
# Out:
#      Name  Age Key
# 0     Jai   27  K0
# 1  Princi   24  K1
# 2  Gaurav   22  K2
# 3    Anuj   32  K3
#
#        Address Qualification
# K0  Allahabad           MCA
# K2    Kannuaj           Phd
# K3  Allahabad          Bcom
# K4    Kannuaj        B.hons
#      Name  Age Key    Address Qualification
# 0     Jai   27  K0  Allahabad           MCA
# 1  Princi   24  K1        NaN           NaN
# 2  Gaurav   22  K2    Kannuaj           Phd
# 3    Anuj   32  K3  Allahabad          Bcom

# %%
# Joining singly-indexed DataFrame with multi-indexed DataFrame :
import pandas as pd 
data1 = {'Name':['Jai', 'Princi', 'Gaurav'], 
        'Age':[27, 24, 22]} 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kanpur'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
df = pd.DataFrame(data1, index=pd.Index(['K0', 'K1', 'K2'], name='key'))
index = pd.MultiIndex.from_tuples([('K0', 'Y0'), ('K1', 'Y1'),
                                   ('K2', 'Y2'), ('K2', 'Y3')],
                                   names=['key', 'Y'])
df1 = pd.DataFrame(data2, index= index)
print(df, "\n\n", df1)
result = df.join(df1, how='inner')
result
# Out:
#        Name  Age
# key
# K0      Jai   27
# K1   Princi   24
# K2   Gaurav   22
#
#            Address Qualification
# key Y
# K0  Y0  Allahabad           MCA
# K1  Y1    Kannuaj           Phd
# K2  Y2  Allahabad          Bcom
#     Y3     Kanpur        B.hons
#           Name  Age    Address Qualification
# key Y
# K0  Y0     Jai   27  Allahabad           MCA
# K1  Y1  Princi   24    Kannuaj           Phd
# K2  Y2  Gaurav   22  Allahabad          Bcom
#     Y3  Gaurav   22     Kanpur        B.hons
